# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/dataset2')
df
# Out:
#     Composition  N_total  Mismatch  Avg at. wt.  avg s val e-  avg p val e  \
# 0         Sb2S3        5 -0.333333    67.943600      2.000000     3.600000
# 1         Sb2S3        5 -0.333333    67.943600      2.000000     3.600000
# 2         Bi2S3        5 -0.333333   102.831748      2.000000     3.600000
# 3        As2Se3        5 -0.333333    77.344636      2.000000     3.600000
# 4        As2Se3        5 -0.333333    77.344636      2.000000     3.600000
# ..          ...      ...       ...          ...           ...          ...
# 498     CuBiSeO        4  0.000000    91.871442      1.750000     2.750000
# 499        BiSe        2  0.000000   143.970185      2.000000     3.500000
# 500     Bi2SeO5        8 -0.666667    72.114717      2.000000     3.750000
# 501     Bi2SeO2        5 -0.333333   105.783908      2.000000     3.600000
# 502   K2Bi8Se13       23 -0.230769   120.718242      1.913043     3.304348
#
#      pnictogen s energy  pnictogen p energy  chalcogen s energy  \
# 0             -0.445605           -0.185623           -0.630912
# 1             -0.445605           -0.185623           -0.630912
# 2             -0.426129           -0.180198           -0.630912
# 3             -0.523670           -0.197497           -0.621248
# 4             -0.426129           -0.180198           -0.621248
# ..                  ...                 ...                 ...
# 498           -0.426129           -0.180198           -0.621248
# 499           -0.426129           -0.180198           -0.621248
# 500           -0.426129           -0.180198           -0.621248
# 501           -0.426129           -0.180198           -0.621248
# 502           -0.426129           -0.180198           -0.621248
#
#      chalcogen p energy  ...  chg s+p energy  Avg Pn-chg EN  Diff Pn-chg EN  \
# 0             -0.261676  ...       -0.892588       2.368000            3.64
# 1             -0.261676  ...       -0.892588       2.368000            3.64
# 2             -0.261676  ...       -0.892588       2.356000            3.70
# 3             -0.245806  ...       -0.867054       2.402000            3.29
# 4             -0.245806  ...       -0.867054       2.402000            3.29
# ..                  ...  ...             ...            ...             ...
# 498           -0.245806  ...       -0.867054       2.285000            0.53
# 499           -0.245806  ...       -0.867054       2.285000            0.53
# 500           -0.245806  ...       -0.867054       2.196667           -1.49
# 501           -0.245806  ...       -0.867054       2.196667           -1.49
# 502           -0.245806  ...       -0.867054       2.348095           16.99
#
#      Ionicity  Hybridisation  Ratio +3 Ph/-2 chg  avg ionic char  \
# 0   -0.310000       2.631579           14.526316        0.016276
# 1   -0.310000       2.631579           14.526316        0.016276
# 2   -0.360000       2.325581            9.435897        0.018097
# 3   -0.070000       2.631579           20.482759        0.008075
# 4   -0.070000       2.631579           20.482759        0.008075
# ..        ...            ...                 ...             ...
# 498 -0.775000       1.183432            1.692308        0.074658
# 499 -0.260000       2.127660            1.692308        0.016954
# 500 -0.626667       2.764977            3.384615        0.078022
# 501 -0.553333       2.608696            3.384615        0.083149
# 502 -0.608000       1.449275          176.000000        0.048368
#
#      avg_polarizability(A^3)  Covalent_Radius  kappa
# 0                   4.380000         0.032400    1.3
# 1                   4.380000         0.032400      1
# 2                   4.700000         0.048400   2.06
# 3                   4.000000         0.000225   0.14
# 4                   4.000000         0.000225    NaN
# ..                       ...              ...    ...
# 498                 4.673250         0.080319      1
# 499                 5.600000         0.022500    0.6
# 500                 2.820625         0.089756    1.1
# 501                 4.037200         0.089756    0.9
# 502                 8.495652         0.108889   1.28
#
# [503 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Composition', 'N_total', 'Mismatch', 'Avg at. wt.', 'avg s val e-',
#        'avg p val e', 'pnictogen s energy', 'pnictogen p energy',
#        'chalcogen s energy', 'chalcogen p energy', 'Pn s+p energy',
#        'chg s+p energy', 'Avg Pn-chg EN', 'Diff Pn-chg EN', 'Ionicity',
#        'Hybridisation', 'Ratio +3 Ph/-2 chg', 'avg ionic char',
#        'avg_polarizability(A^3)', 'Covalent_Radius', 'kappa'],
#       dtype='object')

# %%
columns_to_drop = ['Composition']
df= df.drop(columns=columns_to_drop)
df
# Out:
#      N_total  Mismatch  Avg at. wt.  avg s val e-  avg p val e  \
# 0          5 -0.333333    67.943600      2.000000     3.600000
# 1          5 -0.333333    67.943600      2.000000     3.600000
# 2          5 -0.333333   102.831748      2.000000     3.600000
# 3          5 -0.333333    77.344636      2.000000     3.600000
# 4          5 -0.333333    77.344636      2.000000     3.600000
# ..       ...       ...          ...           ...          ...
# 498        4  0.000000    91.871442      1.750000     2.750000
# 499        2  0.000000   143.970185      2.000000     3.500000
# 500        8 -0.666667    72.114717      2.000000     3.750000
# 501        5 -0.333333   105.783908      2.000000     3.600000
# 502       23 -0.230769   120.718242      1.913043     3.304348
#
#      pnictogen s energy  pnictogen p energy  chalcogen s energy  \
# 0             -0.445605           -0.185623           -0.630912
# 1             -0.445605           -0.185623           -0.630912
# 2             -0.426129           -0.180198           -0.630912
# 3             -0.523670           -0.197497           -0.621248
# 4             -0.426129           -0.180198           -0.621248
# ..                  ...                 ...                 ...
# 498           -0.426129           -0.180198           -0.621248
# 499           -0.426129           -0.180198           -0.621248
# 500           -0.426129           -0.180198           -0.621248
# 501           -0.426129           -0.180198           -0.621248
# 502           -0.426129           -0.180198           -0.621248
#
#      chalcogen p energy  Pn s+p energy  chg s+p energy  Avg Pn-chg EN  \
# 0             -0.261676      -0.631228       -0.892588       2.368000
# 1             -0.261676      -0.631228       -0.892588       2.368000
# 2             -0.261676      -0.606327       -0.892588       2.356000
# 3             -0.245806      -0.721167       -0.867054       2.402000
# 4             -0.245806      -0.606327       -0.867054       2.402000
# ..                  ...            ...             ...            ...
# 498           -0.245806      -0.606327       -0.867054       2.285000
# 499           -0.245806      -0.606327       -0.867054       2.285000
# 500           -0.245806      -0.606327       -0.867054       2.196667
# 501           -0.245806      -0.606327       -0.867054       2.196667
# 502           -0.245806      -0.606327       -0.867054       2.348095
#
#      Diff Pn-chg EN  Ionicity  Hybridisation  Ratio +3 Ph/-2 chg  \
# 0              3.64 -0.310000       2.631579           14.526316
# 1              3.64 -0.310000       2.631579           14.526316
# 2              3.70 -0.360000       2.325581            9.435897
# 3              3.29 -0.070000       2.631579           20.482759
# 4              3.29 -0.070000       2.631579           20.482759
# ..              ...       ...            ...                 ...
# 498            0.53 -0.775000       1.183432            1.692308
# 499            0.53 -0.260000       2.127660            1.692308
# 500           -1.49 -0.626667       2.764977            3.384615
# 501           -1.49 -0.553333       2.608696            3.384615
# 502           16.99 -0.608000       1.449275          176.000000
#
#      avg ionic char  avg_polarizability(A^3)  Covalent_Radius kappa
# 0          0.016276                 4.380000         0.032400   1.3
# 1          0.016276                 4.380000         0.032400     1
# 2          0.018097                 4.700000         0.048400  2.06
# 3          0.008075                 4.000000         0.000225  0.14
# 4          0.008075                 4.000000         0.000225   NaN
# ..              ...                      ...              ...   ...
# 498        0.074658                 4.673250         0.080319     1
# 499        0.016954                 5.600000         0.022500   0.6
# 500        0.078022                 2.820625         0.089756   1.1
# 501        0.083149                 4.037200         0.089756   0.9
# 502        0.048368                 8.495652         0.108889  1.28
#
# [503 rows x 20 columns]

# %%
df = df.dropna()
df
# Out:
#      N_total  Mismatch  Avg at. wt.  avg s val e-  avg p val e  \
# 0          5 -0.333333    67.943600      2.000000     3.600000
# 1          5 -0.333333    67.943600      2.000000     3.600000
# 2          5 -0.333333   102.831748      2.000000     3.600000
# 3          5 -0.333333    77.344636      2.000000     3.600000
# 5          5 -0.333333    96.080000      2.000000     3.600000
# ..       ...       ...          ...           ...          ...
# 498        4  0.000000    91.871442      1.750000     2.750000
# 499        2  0.000000   143.970185      2.000000     3.500000
# 500        8 -0.666667    72.114717      2.000000     3.750000
# 501        5 -0.333333   105.783908      2.000000     3.600000
# 502       23 -0.230769   120.718242      1.913043     3.304348
#
#      pnictogen s energy  pnictogen p energy  chalcogen s energy  \
# 0             -0.445605           -0.185623           -0.630912
# 1             -0.445605           -0.185623           -0.630912
# 2             -0.426129           -0.180198           -0.630912
# 3             -0.523670           -0.197497           -0.621248
# 5             -0.445605           -0.185623           -0.621248
# ..                  ...                 ...                 ...
# 498           -0.426129           -0.180198           -0.621248
# 499           -0.426129           -0.180198           -0.621248
# 500           -0.426129           -0.180198           -0.621248
# 501           -0.426129           -0.180198           -0.621248
# 502           -0.426129           -0.180198           -0.621248
#
#      chalcogen p energy  Pn s+p energy  chg s+p energy  Avg Pn-chg EN  \
# 0             -0.261676      -0.631228       -0.892588       2.368000
# 1             -0.261676      -0.631228       -0.892588       2.368000
# 2             -0.261676      -0.606327       -0.892588       2.356000
# 3             -0.245806      -0.721167       -0.867054       2.402000
# 5             -0.245806      -0.631228       -0.867054       2.350000
# ..                  ...            ...             ...            ...
# 498           -0.245806      -0.606327       -0.867054       2.285000
# 499           -0.245806      -0.606327       -0.867054       2.285000
# 500           -0.245806      -0.606327       -0.867054       2.196667
# 501           -0.245806      -0.606327       -0.867054       2.196667
# 502           -0.245806      -0.606327       -0.867054       2.348095
#
#      Diff Pn-chg EN  Ionicity  Hybridisation  Ratio +3 Ph/-2 chg  \
# 0              3.64 -0.310000       2.631579           14.526316
# 1              3.64 -0.310000       2.631579           14.526316
# 2              3.70 -0.360000       2.325581            9.435897
# 3              3.29 -0.070000       2.631579           20.482759
# 5              3.55 -0.210000       2.380952           15.631579
# ..              ...       ...            ...                 ...
# 498            0.53 -0.775000       1.183432            1.692308
# 499            0.53 -0.260000       2.127660            1.692308
# 500           -1.49 -0.626667       2.764977            3.384615
# 501           -1.49 -0.553333       2.608696            3.384615
# 502           16.99 -0.608000       1.449275          176.000000
#
#      avg ionic char  avg_polarizability(A^3)  Covalent_Radius kappa
# 0          0.016276                 4.380000         0.032400   1.3
# 1          0.016276                 4.380000         0.032400     1
# 2          0.018097                 4.700000         0.048400  2.06
# 3          0.008075                 4.000000         0.000225  0.14
# 5          0.014541                 4.920000         0.012100     1
# ..              ...                      ...              ...   ...
# 498        0.074658                 4.673250         0.080319     1
# 499        0.016954                 5.600000         0.022500   0.6
# 500        0.078022                 2.820625         0.089756   1.1
# 501        0.083149                 4.037200         0.089756   0.9
# 502        0.048368                 8.495652         0.108889  1.28
#
# [233 rows x 20 columns]

# %%
# Convert 'kappa.1' to numeric values
df['kappa'] = pd.to_numeric(df['kappa'], errors='coerce')

df_filtered = df[df['kappa'] <= 2]
# Out:
# <ipython-input-21-e69889d9b755>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kappa'] = pd.to_numeric(df['kappa'], errors='coerce')

# %%
df_filtered
# Out:
#      N_total  Mismatch  Avg at. wt.  avg s val e-  avg p val e  \
# 0          5 -0.333333    67.943600      2.000000     3.600000
# 1          5 -0.333333    67.943600      2.000000     3.600000
# 3          5 -0.333333    77.344636      2.000000     3.600000
# 5          5 -0.333333    96.080000      2.000000     3.600000
# 6          5 -0.333333    96.080000      2.000000     3.600000
# ..       ...       ...          ...           ...          ...
# 498        4  0.000000    91.871442      1.750000     2.750000
# 499        2  0.000000   143.970185      2.000000     3.500000
# 500        8 -0.666667    72.114717      2.000000     3.750000
# 501        5 -0.333333   105.783908      2.000000     3.600000
# 502       23 -0.230769   120.718242      1.913043     3.304348
#
#      pnictogen s energy  pnictogen p energy  chalcogen s energy  \
# 0             -0.445605           -0.185623           -0.630912
# 1             -0.445605           -0.185623           -0.630912
# 3             -0.523670           -0.197497           -0.621248
# 5             -0.445605           -0.185623           -0.621248
# 6             -0.445605           -0.185623           -0.621248
# ..                  ...                 ...                 ...
# 498           -0.426129           -0.180198           -0.621248
# 499           -0.426129           -0.180198           -0.621248
# 500           -0.426129           -0.180198           -0.621248
# 501           -0.426129           -0.180198           -0.621248
# 502           -0.426129           -0.180198           -0.621248
#
#      chalcogen p energy  Pn s+p energy  chg s+p energy  Avg Pn-chg EN  \
# 0             -0.261676      -0.631228       -0.892588       2.368000
# 1             -0.261676      -0.631228       -0.892588       2.368000
# 3             -0.245806      -0.721167       -0.867054       2.402000
# 5             -0.245806      -0.631228       -0.867054       2.350000
# 6             -0.245806      -0.631228       -0.867054       2.350000
# ..                  ...            ...             ...            ...
# 498           -0.245806      -0.606327       -0.867054       2.285000
# 499           -0.245806      -0.606327       -0.867054       2.285000
# 500           -0.245806      -0.606327       -0.867054       2.196667
# 501           -0.245806      -0.606327       -0.867054       2.196667
# 502           -0.245806      -0.606327       -0.867054       2.348095
#
#      Diff Pn-chg EN  Ionicity  Hybridisation  Ratio +3 Ph/-2 chg  \
# 0              3.64 -0.310000       2.631579           14.526316
# 1              3.64 -0.310000       2.631579           14.526316
# 3              3.29 -0.070000       2.631579           20.482759
# 5              3.55 -0.210000       2.380952           15.631579
# 6              3.55 -0.210000       2.380952           15.631579
# ..              ...       ...            ...                 ...
# 498            0.53 -0.775000       1.183432            1.692308
# 499            0.53 -0.260000       2.127660            1.692308
# 500           -1.49 -0.626667       2.764977            3.384615
# 501           -1.49 -0.553333       2.608696            3.384615
# 502           16.99 -0.608000       1.449275          176.000000
#
#      avg ionic char  avg_polarizability(A^3)  Covalent_Radius  kappa
# 0          0.016276                 4.380000         0.032400   1.30
# 1          0.016276                 4.380000         0.032400   1.00
# 3          0.008075                 4.000000         0.000225   0.14
# 5          0.014541                 4.920000         0.012100   1.00
# 6          0.014541                 4.920000         0.012100   0.90
# ..              ...                      ...              ...    ...
# 498        0.074658                 4.673250         0.080319   1.00
# 499        0.016954                 5.600000         0.022500   0.60
# 500        0.078022                 2.820625         0.089756   1.10
# 501        0.083149                 4.037200         0.089756   0.90
# 502        0.048368                 8.495652         0.108889   1.28
#
# [219 rows x 20 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(15, 13))
plt.rcParams['figure.dpi'] = 1200
plt.xticks(weight='bold', fontsize=10)
plt.yticks(weight='bold', fontsize=10)

# Create a heatmap with 'coolwarm' palette and annotations
sns.heatmap(corr,
            cmap='coolwarm', vmax=1.0, vmin=-1.0, linewidths=0.1, square=True)

# Title and adjustments
plt.title('Correlation Heatmap', fontsize=14, weight='bold')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-7-17e6887b812e>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
pip install ppscore
# Out:
# Requirement already satisfied: ppscore in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ppscore) (1.5.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from ppscore) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.0.0->ppscore) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=0.20.2->ppscore) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.0.0->ppscore) (1.16.0)

# %%
import matplotlib.pyplot as plt
import ppscore as pps
import seaborn as sns
corr_matrix = df.corr(method='spearman')
from matplotlib import font_manager
from sklearn.preprocessing import MinMaxScaler
plt.figure(figsize=(12, 10))  # Adjust the figure size as needed
sns.heatmap(corr_matrix, vmax=1.0, vmin=-1.0, cmap='PiYG', square=True)

# Set font properties for tick labels
font_path = font_manager.FontProperties().get_file()
font_prop = font_manager.FontProperties(fname=font_path, weight='bold')

# Adjust x-axis and y-axis tick label font size and rotation
plt.xticks(fontproperties=font_prop, rotation=90, ha='right', fontsize=10)
plt.yticks(fontproperties=font_prop, rotation=0, fontsize=10)

# Set title if needed
# plt.title('Spearmans Rank Correlation Coefficient Matrix', fontweight='bold')

plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
